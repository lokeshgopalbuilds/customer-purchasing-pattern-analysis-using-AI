# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# ##### Data Exploration

# %% [markdown]
# - Reading csv from the data folder

# %%
import pandas as pd

# %%
# For Reading data from csv file 
df = pd.read_csv('../data/raw/synthetic_customers.csv')

# %%
# For checking 1st 5 rows of data
df.head()
# Out:
#    customer_id  age  gender region   device signup_date last_purchase_date  \
# 0            1   23  Female   East   Mobile  2022-10-30         2022-10-31
# 1            2   66  Female  North   Mobile  2022-06-23         2024-02-17
# 2            3   59    Male  North   Mobile  2023-02-27         2023-05-23
# 3            4   45    Male   West  Desktop  2023-11-29         2025-05-17
# 4            5   45  Female  South   Mobile  2019-06-02         2019-06-14
#
#    purchase_count preferred_category loyalty_tier  avg_order_value  \
# 0               0          Groceries       Bronze            34.77
# 1               4          Groceries       Silver            44.53
# 2               0           Clothing       Bronze            64.93
# 3               4               Home       Silver            45.49
# 4               0          Groceries       Bronze            43.67
#
#    coupon_used_pct payment_method  total_spent  recency_days  churned
# ...

# %%
# For checking 1st 5 rows of data
df.tail()
# Out:
#        customer_id  age  gender   region   device signup_date  \
# 14995        14996   49  Female  Central  Desktop  2020-02-25
# 14996        14997   52    Male    South   Mobile  2021-07-08
# 14997        14998   59  Female    North  Desktop  2021-08-15
# 14998        14999   47  Female    South   Mobile  2020-03-26
# 14999        15000   19    Male  Central   Mobile  2019-08-16
#
#       last_purchase_date  purchase_count preferred_category loyalty_tier  \
# 14995         2021-08-26               3             Beauty       Silver
# 14996         2023-03-07               5               Home       Bronze
# 14997         2022-01-16               1              Books       Silver
# 14998         2021-12-31              10          Groceries       Silver
# 14999         2019-09-06               0             Sports       Bronze
#
#        avg_order_value  coupon_used_pct payment_method  total_spent  \
# 14995            46.65            0.234     Debit Card       137.01
# ...

# %%
# to see the df rows count 
df.shape
# Out:
# (15000, 16)

# %%
# To see the datatypes 
df.dtypes
# Out:
# customer_id             int64
# age                     int64
# gender                    str
# region                    str
# device                    str
# signup_date               str
# last_purchase_date        str
# purchase_count          int64
# preferred_category        str
# loyalty_tier              str
# avg_order_value       float64
# coupon_used_pct       float64
# payment_method            str
# total_spent           float64
# recency_days            int64
# churned                 int64
# dtype: object

# %%
# To See the whole information 
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         15000 non-null  int64
#  1   age                 15000 non-null  int64
#  2   gender              15000 non-null  str
#  3   region              15000 non-null  str
#  4   device              15000 non-null  str
#  5   signup_date         15000 non-null  str
#  6   last_purchase_date  15000 non-null  str
#  7   purchase_count      15000 non-null  int64
#  8   preferred_category  15000 non-null  str
#  9   loyalty_tier        15000 non-null  str
#  10  avg_order_value     15000 non-null  float64
#  11  coupon_used_pct     15000 non-null  float64
#  12  payment_method      15000 non-null  str
#  13  total_spent         15000 non-null  float64
#  14  recency_days        15000 non-null  int64
#  15  churned             15000 non-null  int64
# ...

# %%
# To get to know the statistics of df 
df.describe()
# Out:
#         customer_id           age  purchase_count  avg_order_value  \
# count  15000.000000  15000.000000    15000.000000     15000.000000
# mean    7500.500000     48.780067        2.829600        60.183585
# std     4330.271354     18.112838        2.417634        50.734020
# min        1.000000     18.000000        0.000000         4.430000
# 25%     3750.750000     33.000000        1.000000        27.890000
# 50%     7500.500000     49.000000        2.000000        45.415000
# 75%    11250.250000     64.000000        4.000000        75.620000
# max    15000.000000     80.000000       14.000000       840.660000
#
#        coupon_used_pct   total_spent  recency_days       churned
# count     15000.000000  15000.000000  15000.000000  15000.000000
# mean          0.336185    170.581837    942.790067      0.712200
# std           0.160888    242.107731    716.448198      0.452752
# min           0.005000      0.000000      0.000000      0.000000
# ...

# %%
# To get to know the statistics of df (non numerical cols )
df.describe(include='object')
# Out:
# C:\Users\gorla\AppData\Local\Temp\ipykernel_16260\436763538.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include='object')
#         gender region  device signup_date last_purchase_date  \
# count    15000  15000   15000       15000              15000
# unique       3      5       3        2546               2424
# top     Female  North  Mobile  2024-03-20         2025-12-31
# freq      7498   3272    9723          16               2205
#
#        preferred_category loyalty_tier payment_method
# ...

# %% [markdown]
# ##### Data Cleaning
# - 1. Null Values
# - 2. Duplicates
# - 3. Outliers
# - 4. Anamoly Detection (Data Inconsitency)
# - 5. Interpolation

# %%
# df.isnull() # 1 : Finding Null values (Operation)
# df[df.isnull()] # 2 : Get the above result in dataframe (To get the operation result in df df[operation])
# Out:
#        customer_id  age gender region device signup_date last_purchase_date  \
# 0              NaN  NaN    NaN    NaN    NaN         NaN                NaN
# 1              NaN  NaN    NaN    NaN    NaN         NaN                NaN
# 2              NaN  NaN    NaN    NaN    NaN         NaN                NaN
# 3              NaN  NaN    NaN    NaN    NaN         NaN                NaN
# 4              NaN  NaN    NaN    NaN    NaN         NaN                NaN
# ...            ...  ...    ...    ...    ...         ...                ...
# 14995          NaN  NaN    NaN    NaN    NaN         NaN                NaN
# 14996          NaN  NaN    NaN    NaN    NaN         NaN                NaN
# 14997          NaN  NaN    NaN    NaN    NaN         NaN                NaN
# 14998          NaN  NaN    NaN    NaN    NaN         NaN                NaN
# 14999          NaN  NaN    NaN    NaN    NaN         NaN                NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# customer_id           0
# age                   0
# gender                0
# region                0
# device                0
# signup_date           0
# last_purchase_date    0
# purchase_count        0
# preferred_category    0
# loyalty_tier          0
# avg_order_value       0
# coupon_used_pct       0
# payment_method        0
# total_spent           0
# recency_days          0
# churned               0
# dtype: int64

# %%
# df.duplicated()
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, age, gender, region, device, signup_date, last_purchase_date, purchase_count, preferred_category, loyalty_tier, avg_order_value, coupon_used_pct, payment_method, total_spent, recency_days, churned]
# Index: []

# %%
df.drop_duplicates()

# %%
df.describe()
# Out:
#         customer_id           age  purchase_count  avg_order_value  \
# count  15000.000000  15000.000000    15000.000000     15000.000000
# mean    7500.500000     48.780067        2.829600        60.183585
# std     4330.271354     18.112838        2.417634        50.734020
# min        1.000000     18.000000        0.000000         4.430000
# 25%     3750.750000     33.000000        1.000000        27.890000
# 50%     7500.500000     49.000000        2.000000        45.415000
# 75%    11250.250000     64.000000        4.000000        75.620000
# max    15000.000000     80.000000       14.000000       840.660000
#
#        coupon_used_pct   total_spent  recency_days       churned
# count     15000.000000  15000.000000  15000.000000  15000.000000
# mean          0.336185    170.581837    942.790067      0.712200
# std           0.160888    242.107731    716.448198      0.452752
# min           0.005000      0.000000      0.000000      0.000000
# ...

# %%
import numpy as np 
Q3 = np.percentile(df['age'],0.75)
Q1 = np.percentile(df['age'],0.25)

IQR = Q3-Q1

lower_limit = IQR*1.5 + Q1
upper_limit = IQR*1.5 + Q3


Q1,Q3,IQR,lower_limit,upper_limit

# %%
df['age'].unique()

# %%
df['age'].value_counts()

# %%
df['age'].percentile(0.75)

# %%
age = 0

df[df['age'] == '19+E0'].drop()

# %%
df.drop()

# %% [markdown]
# ##### Operaters

# %% [markdown]
# - 1. Arthimeitc
# - 2. Logical
# - 3. Boolean
# - 4. Comparision
# - 5. Membership
# - 6. Aggregation

# %%
df['age'] + 10

# %%
df['BMI'] = df['age']*1.5 + df['weight']*0.69

# %%
df[(df['age']> 10) and (df['gender'] == 'F')] # and 
df[(df['age']> 10) or (df['gender'] == 'F')] # or 
df[(df['age']> 10) not (df['gender'] == 'F')] # or 
df[~df['gender'] == 'M']

# %%
df[~df['age'].isin([10,20,30])]

# %% [markdown]
# ##### Common Functions

# %% [markdown]
# ##### Joins
